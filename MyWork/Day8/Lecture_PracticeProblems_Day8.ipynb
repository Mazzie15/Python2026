# %% [markdown]
# ## Intro to Python Programming
# - Prof Joanna Bieri
# - Office: Duke 209
#
# ### Day 8 - User Inputs and While Loops
#
#    - User Inputs: In so many of our examples thus far, we have started by asking for information. For example, in the Disneyland code we needed to know a person's age and how many days the were visiting. Normally, you don't want your user to have to open up your code to make these changes. User inputs let your code ask the user directly for data.
#
#    - While Loops: These are just a different type of loop that allow your code to keep running a set of commands until a condition is met. Remember, For loops run for a specific set of runs based on your data. But what if you want to keep going until something is true about your data?

# %% [markdown]
# ### User Inputs
#
# The input() function lets you write a message to the user, they respond by typing something in, and then it saves the information as a string.

# %%
prompt = 'Type in your name:'
name = input(prompt)

print(f"\nHello {name} you are amazing!")
# Out:
# Type in your name: Mazzie
# Hello Mazzie you are amazing!

# %%
prompt = '\nIf you give me your name I will print a motivational message!'
prompt += '\nType in your name:'
name = input(prompt)


print(f"\nHello {name} you are amazing!")
# Out:
# If you give me your name I will print a motivational message!
# Type in your name: Mazzie
# Hello Mazzie you are amazing!

# %% [markdown]
# #### Be careful, input will always assume it is reading a string!

# %%
prompt = 'Type in your favorite number:'
number = input(prompt)

print(f'You inputed {number} which I think is a data type {type(number)}')
# Out:
# Type in your favorite number: 5
# You inputed 5 which I think is a data type <class 'str'>

# %%
prompt = 'Type in your favorite number:'
number = int(input(prompt))

print(f'You inputed {number} which I think is a data type {type(number)}')
# Out:
# Type in your favorite number: 3
# You inputed 3 which I think is a data type <class 'int'>

# %% [markdown]
# #### Pratice Problem
#
# Write code that takes two different inputs and gives the users clear prompts:
#  - First ask their favorite food.
#  - Then ask how much they would pay for that food right now. Use the food entered to update the prompt. This should be a float.
#  - Finally print a message that reports back to the that they are in luck, their favorite food is on sale and now costs only {60% of what they would pay}.

# %%
# Your code here:

prompt1 = 'Type in your favorite food:'
food = input(prompt1)
print(f"\n{food} is your favorite food!")

prompt2 = 'How much do you pay for the food right now?:'
pay = float(input(prompt2))
print(f'You inputed {pay} which I think is a data type {type(pay)}')

print(f'Congratulations! {food} only cost ${pay* 0.6}!')
# Out:
# Type in your favorite food: beans
# beans is your favorite food!
# How much do you pay for the food right now?: 1.99
# You inputed 1.99 which I think is a data type <class 'float'>
# Congratulations! beans only cost $1.194!

# %% [markdown]
# ### A useful operation: Modulo
#
# In many places clocks report the time from 0-24 hours so that you don't have to keet track of am vs pm. For example 8am = 8:00 and 8pm = 20:00. We will use modulo to make a time converter.

# %%
# Modulo
prompt = 'Enter the hours on your 24 hour clock: '
hours = int(input(prompt))
prompt = 'Enter the minutes on your 24 hours clock: '
minutes = input(prompt)

twelve_hour_time = hours % 12

if twelve_hour_time == 0:
    twelve_hour_time = 12

if hours < 12:
    ampm = 'am'
elif hours >= 12:
    ampm = 'pm'

print(f'The time is {twelve_hour_time}:{minutes}{ampm}.')
# Out:
# Enter the hours on your 24 hour clock:  16
# Enter the minutes on your 24 hours clock:  34
# The time is 4:34pm.

# %% [markdown]
# #### Pratice Problem
#
# Write code that asks a user to input a number and then uses the modulo function to print whether the number is even or odd.

# %%
# Your code here

prompt = ('Your number: ')
yournumber = int(input(prompt))
if yournumber % 2 ==0:
    print('Your number is even!')
else:
    print('Your number is odd!')
# Out:
# Your number:  1234
# Your number is even!

# %% [markdown]
# ### While Loop
#
# While loop? While not!
#
# These are great for continuing a process until a condition is met.

# %%
# Enter what classes you are taking:
prompt = "\nEnter another class you are taking:"
classes = []

while len(classes) < 4: 
    class_name = input(prompt)
    classes.append(class_name)
    
print(f'\Here is your list of classes: {classes}')
# Out:
# Enter another class you are taking: art
#
# Enter another class you are taking: history
#
# Enter another class you are taking: math
#
# Enter another class you are taking: science
# \Here is your list of classes: ['art', 'history', 'math', 'science']

# %%
# But wait!
# What if someone is only taking three classes or is actually taking 5 classes?
# What if they accidentally enter the same class twice?

prompt = "\nEnter another class you are taking:"
prompt += "\nWhen you are done entering classes type 'stop'."
classes = []
class_name = ''
while class_name != 'stop':
    class_name = input(prompt)
    if class_name != 'stop':
        if class_name not in classes:
            classes.append(class_name)
        else:
            print(f'You already entered {class_name}.')
    
    
print(f'\Here is your list of classes: {classes}')
# Out:
# Enter another class you are taking:
# When you are done entering classes type 'stop'. math
#
# Enter another class you are taking:
# When you are done entering classes type 'stop'. art
#
# Enter another class you are taking:
# When you are done entering classes type 'stop'. history
#
# Enter another class you are taking:
# When you are done entering classes type 'stop'. stop
# \Here is your list of classes: ['math', 'art', 'history']

# %% [markdown]
# ### Practice Problems
#
# 1. Write code that uses a while loop to prompt a user to start entering their 5 favorite animals. Save those animals to a list. Make sure there are no repeats. Print out a message with the list of animals. Make sure your code won't let them add 9.
#
# 2. Now write a for loop that loops through the list of animals and asks the user what each animal eats. Save the animal and food in a dictionary (animal is the key and the food is the value: eg: animal_dict = {'cat':'fish'}). Print out the dictionary.

# %%
# Your code here

prompt = "\nEnter your favorite animals:"
animals = []
animal_name = ''
while len(animals) < 5: 
    animal_name = input(prompt)
    if animals == "9":
        print("Invalid. Please enter another animal:")
    elif animal_name not in animals:
        animals.append(animal_name)
    else:
        print(f'You already entered {animal_name}.')
print(f"Your 5 favorite animals are: {animals}")

# food = []
# animal_food = ''

animal_dict = {}
# prompt2 = "\nWhat does a {animal} eat:"
for i in animals:
    food = input(f"What does a {i} eat: ")
    animal_dict[i] = food
print(animal_dict)
# Out:
# Enter your favorite animals: snake
#
# Enter your favorite animals: cat
#
# Enter your favorite animals: dog
#
# Enter your favorite animals: shark
#
# Enter your favorite animals: horse
# Your 5 favorite animals are: ['snake', 'cat', 'dog', 'shark', 'horse']
# What does a snake eat:  mice
# What does a cat eat:  fish
# What does a dog eat:  kibble
# What does a shark eat:  people
# What does a horse eat:  hay
# {'snake': 'mice', 'cat': 'fish', 'dog': 'kibble', 'shark': 'people', 'horse': 'hay'}

# %% [markdown]
# ### Flag, Break, and Continue
#
#    - You can use a flag variable to run a while loop until a boolean goes from True to False
#    - You can use the 'break' command to stop a loop in it's tracks
#    - You can use a 'continue' command to skip some parts of a loop

# %%
# FLAGS
# Here is a guessing game
# The flag got_it only changes from False to True if the person makes the right guess
# The while loop keeps going as long as got_it is False.

my_word = 'bat'
prompt = "Enter a three letter word:"
prompt += "\nType 'quit' to give up."

print('Try to guess my three letter animal:')
got_it = False #Flag
num_guesses = 0

while not got_it:
    word = input(prompt)
    if len(word) != 3:
        if word == 'quit':
            got_it = True
            print(f'    You gave up after {num_guesses} guesses')
        else:
            print("    You wasted a guess - that word was not three letters!")
            num_guesses += 1
    elif word == my_word:
        print(f"    You got it in {num_guesses+1} guesses! {word} was my three letter animal")
        got_it = True
    else:
        num_guesses += 1
        print(f"   Wrong guess! You have made {num_guesses} guesses")
# Out:
# Try to guess my three letter animal:
# Enter a three letter word:
# Type 'quit' to give up. cat
#    Wrong guess! You have made 1 guesses
# Enter a three letter word:
# Type 'quit' to give up. dog
#    Wrong guess! You have made 2 guesses
# Enter a three letter word:
# Type 'quit' to give up. bird
#     You wasted a guess - that word was not three letters!
# Enter a three letter word:
# Type 'quit' to give up. bat
#     You got it in 4 guesses! bat was my three letter animal

# %%
# BREAK
# Lets you stop code in its tracks!
# In this code we break the while loop once the user says quit.
colors = []
print('Enter as many colors as you can think of.')

prompt = 'Enter a color'
prompt += ' or type "quit":'

while True:
    color = input(prompt)
    if color == 'quit':
        break
    else:
        if color in colors:
            print(f'\nYou already guessed {color}')
        else:
            colors.append(color)
            print(f'\nSo far you have: {colors}.')
print('-----------------------------')
print(f'You finished with {len(colors)} colors:')
print(colors)
# Out:
# Enter as many colors as you can think of.
# Enter a color or type "quit": red
# So far you have: ['red'].
# Enter a color or type "quit": blue
# So far you have: ['red', 'blue'].
# Enter a color or type "quit": green
# So far you have: ['red', 'blue', 'green'].
# Enter a color or type "quit": red
# You already guessed red
# Enter a color or type "quit": quit
# -----------------------------
# You finished with 3 colors:
# ['red', 'blue', 'green']

# %%
# CONTINUE
# Lets the loop keep going without finishing the current run
# In this code we continue to the next prompt unless there are three people in the single_group list
prompt = "How many people per group. \nEnter a number:"
num_g = int(input(prompt))

single_group = []
all_groups = []
prompt = 'Enter a name to add to the group \n type "quit" when you are done.'

while True:
    name = input(prompt)
    if name == 'quit':
        break
    single_group.append(name)
    if len(single_group) % num_g != 0:
        continue 
    else:
        all_groups.append(single_group)
        single_group = []

i=0
while len(single_group) != 0:
    all_groups[i].append(single_group.pop())
    i += 1
    
print(all_groups)
# Out:
# How many people per group.
# Enter a number: 3
# Enter a name to add to the group
#  type "quit" when you are done. Maz
# Enter a name to add to the group
#  type "quit" when you are done. Aimee
# Enter a name to add to the group
#  type "quit" when you are done. Steve
# Enter a name to add to the group
#  type "quit" when you are done. Sydney
# Enter a name to add to the group
#  type "quit" when you are done. Jack
# Enter a name to add to the group
#  type "quit" when you are done. Luna
# Enter a name to add to the group
#  type "quit" when you are done. Max
# Enter a name to add to the group
#  type "quit" when you are done. Lucy
# Enter a name to add to the group
#  type "quit" when you are done. quit
# [['Maz', 'Aimee', 'Steve', 'Lucy'], ['Sydney', 'Jack', 'Luna', 'Max']]

# %% [markdown]
# ### There are lots of other advanced things you can do with while loops!
#
# They interact well with lists and dictionaries!

# %%
# Say I want to move names from one list to another, but check that the names are not repeated.
# Like Programming Assignment 3.
# Here we use while to keep running until a list is empty.

current_names = ['Joanna','Ross','Stefanie']
current_ages = [44,44,75]
new_names = ['Joanna','Bella','Kristin']
new_ages = [44,18,40]

while new_names:
    name = new_names.pop()
    if name in current_names:
        continue
    else:
        age = new_ages.pop()
        if age > 21:
            current_names.append(name)
            current_ages.append(age)
        else:
            print(f"{name} is too young!")
            
print(current_names)
print(new_names)
# Out:
# Bella is too young!
# ['Joanna', 'Ross', 'Stefanie', 'Kristin']
# []

# %%
# Say I have a list of users, but somehow a bunch of names got repeated!
names = ['Joanna', 'Ross', 'Stefanie', 'Kristin']
# Artificially ruin the list:
import numpy as np
for i in range(20):
    num = np.random.randint(len(names))
    names.append(names[num])
    
print("My list of usernames is all messed up. There are repeated names!\n")    
print(names)

print('-------------------------')
# Now let's fix this mess
repeates = True
unique_names = []
while repeates:
    if len(names) == 0:
        repeates = False
    else:
        name = names.pop()
        while name in names:
            names.remove(name)
        unique_names.append(name)
        
print('Here is the final list with just the unique names:\n')
print(unique_names)
# Out:
# My list of usernames is all messed up. There are repeated names!
#
# ['Joanna', 'Ross', 'Stefanie', 'Kristin', 'Ross', 'Kristin', 'Stefanie', 'Kristin', 'Stefanie', 'Stefanie', 'Ross', 'Stefanie', 'Kristin', 'Stefanie', 'Joanna', 'Kristin', 'Ross', 'Ross', 'Joanna', 'Stefanie', 'Joanna', 'Stefanie', 'Joanna', 'Joanna']
# -------------------------
# Here is the final list with just the unique names:
#
# ['Joanna', 'Stefanie', 'Ross', 'Kristin']

# %% [markdown]
# # BEWARE!
#
# ### The infinite loop
#
# WHILE loops are great but they can end up be infinite, meaning they will never stop!
#
# ### This is an infinite loop... You will have to hit the stop button to stop it!
#
#     biggest_x = 20
#     x = 1
#     while x < biggest_x:
#         print(x**2)
#         # We have to update x or all this will ever print is 1^2

# %%
# Copy and paste the code here to see what it does.
# Can you fix it?

biggest_x = 20
x = 1
while x < biggest_x:
    print(x**2)
    x += 1
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361

# %% [markdown]
# ### Challenge Problem:
#
# Write a while loop that adds users to your user dictionary and saves information about them. This should be a dictionary of dictionaries.
# - If you would rather think of something you might want to track for research (eg: astronomical features you are cataloging (planets for example)) or something you are tracking for a collection (eg: Pokemon cards) you can make a dictionary of those things instead.
#
# While the users want to keep adding their informaiton your code shoud:
# - first ask for a name - this becomes the dictionary key.
# - Then for each user gather information you think your business or research or collection might need and add that to the users dictionary. This could be things like email address, phone number, best contact times, product interests, etc
#
#
# eg. I have a business of finding stray cats a home and I want to create a list of people who would give a cat a home. My final dictionary would look something like:

# %%
my_clients = {
    "Ross Conkey" : {"email":"ross@gmail.com",
                     "phone":"909-847-6309",
                     "best contact method":"text",
                     "age of desired cat":'any',
                     'color of desired cat':'black',
                     'other info': "none"},
    "Bongo Bob" : {"email":"bongo@aol.com",
                     "phone":"none",
                     "best contact method":"emial",
                     "age of desired cat":'kitten',
                     'color of desired cat':'any',
                     'other info': "I am a cat"}
    
}

for k,v in my_clients.items():
    print(k)
    print("------------------")
    print(v)
    print('------------------')
# Out:
# Ross Conkey
# ------------------
# {'email': 'ross@gmail.com', 'phone': '909-847-6309', 'best contact method': 'text', 'age of desired cat': 'any', 'color of desired cat': 'black', 'other info': 'none'}
# ------------------
# Bongo Bob
# ------------------
# {'email': 'bongo@aol.com', 'phone': 'none', 'best contact method': 'emial', 'age of desired cat': 'kitten', 'color of desired cat': 'any', 'other info': 'I am a cat'}
# ------------------

# %%
# Your code here:
