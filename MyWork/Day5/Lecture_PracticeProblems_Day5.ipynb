# %% [markdown]
# ## Intro to Python Programming
# - Prof Joanna Bieri
# - Office: Duke 209
#
# ### Day 5 - Conditionals and If Statements

# %% [markdown]
# #### Sometimes we want to check if something is true or false:
#
# Some examples:
# - You only want to look at pieces of data that match a certain date range.
# - You only want people who are older than a certain age to play your game.
# - If the user inputs junk, you want your code to tell them so.
# - You might want your code to do different things depending on certain variables.
#
#
# ##### Conditional Checks
#
# - Equal ==
# - Not Equal !=
# - Less Than <
# - Greater Than >
# - Less Than or Equal <=
# - Greater Than or Equal >=
#
# AND --> All things are True
#
# OR --> At least one of the things are True

# %%
# Lets program a mini game
# Guess my number
# Guess a number between 1-100 (integers)

my_number = 42
your_guess = 42

print(my_number == your_guess)
# Out:
# True

# %%
# Lets program a mini game
# Guess the computers number
# Guess a number between 1-10 (integers)
# This time let the computer choose the number
import numpy as np
computers_number = np.random.randint(11) #generate a random number between 0 and 10
your_guess = 5

print(f"Your guess was {computers_number == your_guess}," \
      f" the computers number was {computers_number}!")
# Out:
# Your guess was False, the computers number was 3!

# %%
# Lets try a few conditional Statements
name = "Joanna"
print(name == "Joanna")
print(name == 'joanna')
print(name != "Joanna")
# Out:
# True
# False
# False

# %%
# What if you wanted to check two parts of a name
first = "Joanna" 
last = "Bieri"
test1 = first == "Joanna" and last == "Bieri"
print(test1)

test2 = first == "Bongo" and last =="Bieri"
print(test2)
# Out:
# True
# False

# %%
# What if you want to accept two names
name = "Bongo"
nickname = "Budders"

test1 = name == "Bongo" or nickname == "Budders"
print(test1)

test2 = name == "Bongo" or nickname == "Bob"
print(test2)
# Notice that test2 gives a True because the first condition is met

test3 = name == "Bella" or nickname == "Bob"
print(test3)
# test3 shows that neither condition is met.
# Out:
# True
# True
# False

# %% [markdown]
# #### Booleans
#
# All of these things that are being printed are Booleans: True or False.

# %%
# We can set a variable to be a boolean
# Notice how Python highlights True and False
hungry = True
have_food = True

print(f"I am going to eat something right now.\n    That statement is {hungry == have_food}")
# Out:
# I am going to eat something right now.
#     That statement is True

# %%
# The capitalization matters
hungry = True

# %% [markdown]
# #### Functions and Booleans
#
# Many functions or operations will return a boolean. For example we can check if something is in a list

# %%
my_fruits = ['apple','banana','orange','grape','cherry']

print("cherry" in my_fruits)
print("strawberry" in my_fruits)

# It has to be an exact match.
print('Cherry'.lower() in my_fruits)
# Out:
# True
# False
# True

# %% [markdown]
# #### Practice Problems
#
# 1. Write a conditional statement using each of the different conditional checks listed above. Print out what you expect each boolean to be. For example:
#
#         cat = "bongo"
#         print("This should be True")
#         print (cat == "bongo")
#
#         age = 21
#         print("This should be False")
#         print(age < 21)
#
# 2. Use the following list (you can copy and paste it):
#
#         colors = ['red','green','BLUE','Purple','black']
#
# write conditional statements that check the following:
# - Is red in the list
# - Is pink in the list
# - Is blue in the list (hint use the .lower() function)
# - Are BOTH red and great in the list.
# - Are EITHER red or pink in the list.

# %%
place = "Chicago"
print("This should be True")
print (place == "Chicago")
# Out:
# This should be True
# True

# %%
colors = ['red','green','BLUE','Purple','black']

print('red' in colors)
print('pink' in colors)
print('blue'.lower in colors)
test2 = 'red' and 'great' in colors
print(test2)
test3 = colors = 'red' or 'pink' in colors
print(test3)
# Out:
# True
# False
# False
# False
# red

# %% [markdown]
# #### If statements
#
# These are super important to writing code. So often you want to only do something in your code IF something is true.

# %%
# Lets update the guess my number game:

# Guess the computers number
# Guess a number between 1-10 (integers)
# This time let the computer choose the number
import numpy as np
computers_number = np.random.randint(11) #generate a random number between 0 and 10
your_guess = 10

# This time we can say you won!
print(f"Your guess was {your_guess}," \
      f" the computers number was {computers_number}.")

if computers_number == your_guess:
    print("You Win!")
# Out:
# Your guess was 10, the computers number was 0.

# %%
# Code that uses a FOR loop and an IF statement
user_names = ['Joanna','Kristin','Ross','Stefanie','David','Bongo']

for name in user_names:
    print('-------------------------')
    print(f"Hello there {name}")
    if name == "Bongo":
        print("You are a cat!")
# Out:
# -------------------------
# Hello there Joanna
# -------------------------
# Hello there Kristin
# -------------------------
# Hello there Ross
# -------------------------
# Hello there Stefanie
# -------------------------
# Hello there David
# -------------------------
# Hello there Bongo
# You are a cat!

# %% [markdown]
# #### If-Else statements
#
# These are great for doing different things depending on an if statement.

# %%
# Lets update the guess my number game:

# Guess the computers number
# Guess a number between 1-10 (integers)
# This time let the computer choose the number
import numpy as np
computers_number = np.random.randint(11) #generate a random number between 0 and 10
your_guess = 10

# This time we can say you won!
print(f"You guess was {your_guess}," \
      f" the computers number was {computers_number}.")

if computers_number == your_guess:
    print("You Win!")
else:
    print('You Lose!')
# Out:
# You guess was 10, the computers number was 4.
# You Lose!

# %%
# Update the for loop:

user_names = ['Joanna','Kristin','Ross','Stefanie','David','Bongo']

for name in user_names:
    print('-------------------------')
    print(f"Hello there {name}")
    if name == "Bongo":
        print("You are a cat!")
    else:
        print("You are a human!")
# Out:
# -------------------------
# Hello there Joanna
# You are a human!
# -------------------------
# Hello there Kristin
# You are a human!
# -------------------------
# Hello there Ross
# You are a human!
# -------------------------
# Hello there Stefanie
# You are a human!
# -------------------------
# Hello there David
# You are a human!
# -------------------------
# Hello there Bongo
# You are a cat!

# %% [markdown]
# #### Practice Problems
#
# 3. Game: Choose a door! Write code where you set a variable "door number" equal to either one two or three. Then define a list that contains prizes that are behind each door. Then write three if statements, one for each door, that prints out what prize is won. For example:
#
#         door_number = 3
#         prizes = ['refrigerator','vacation to Hawaii','an old shoe']
#
#         # If the door_number is 1 then the person won prizes[0]
#
#         # If the door_number is 2 then the person won prizes[1]
#
#         # If the door_number is 3 then the person won prizes[2]

# %%
door_number = 3
prizes = ['refrigerator','vacation to Hawaii','an old shoe']
        
print(f"You won a nice {prizes[0]}!")
print(f"You won an experience of a lifetime: a {prizes[1]}!")
print(f"You won... {prizes[2]}! womp womp")
# Out:
# You won a nice refrigerator!
# You won an experience of a lifetime: a vacation to Hawaii!
# You won... an old shoe! womp womp

# %% [markdown]
# #### Practice Problems
#
# 4. Create a list of items along with a category for that time. For example:
#
#         my_things = ['car','sweater','computer','jeans','watch']
#         can_i_wear_it = ['not clothes','clothes','not clothes','clothes','not clothes']
#
# then use a FOR loop to loop through the things and test whether or not they match the category using an IF statement. For me I would check does
#
#         can_i_wear_it[i]=="clothes"
#
# print a different print statement depending on the outcome. So if it is clothes maybe I print "I like to wear {my_things[i]}" and if it is not clothes I print "I like to use {ma_things[i]}.
#
# be creative and have some fun here.

# %%
my_things = ['car','sweater','computer','jeans','watch']
can_i_wear_it = ['not clothes','clothes','not clothes','clothes','not clothes']

for juicy in range(len(my_things)):
    print('-------------------------')
    print(f"I like to wear {can_i_wear_it[juicy]}.")
    if can_i_wear_it[juicy]=="clothes":
        print(f"I like to use {my_things[juicy]}.")
# Out:
# -------------------------
# I like to wear not clothes.
# -------------------------
# I like to wear clothes.
# I like to use sweater.
# -------------------------
# I like to wear not clothes.
# -------------------------
# I like to wear clothes.
# I like to use jeans.
# -------------------------
# I like to wear not clothes.

# %% [markdown]
# #### Practice Problems
#
# 5. Write code that prints out admission rates depending on someones age. Start by defining a variable my_age. Then write an IF-ELSE statement that will print a message about the price of admissions:
#
# - Children under the age of 12 are free
# - Above the age of 12 admission costs $40

# %%
my_age = np.random.randint(101, size=10)

for i in my_age:
    print('-------------------------')
    print(f"You are {i} years old kind sir.")
    if i < 12:
        print(f"You are free!")
    else:
        print(f"You owe me $40! Pay up old man")
# Out:
# -------------------------
# You are 98 years old kind sir.
# You owe me $40! Pay up old man
# -------------------------
# You are 34 years old kind sir.
# You owe me $40! Pay up old man
# -------------------------
# You are 9 years old kind sir.
# You are free!
# -------------------------
# You are 53 years old kind sir.
# You owe me $40! Pay up old man
# -------------------------
# You are 59 years old kind sir.
# You owe me $40! Pay up old man
# -------------------------
# You are 87 years old kind sir.
# You owe me $40! Pay up old man
# -------------------------
# You are 92 years old kind sir.
# You owe me $40! Pay up old man
# -------------------------
# You are 91 years old kind sir.
# You owe me $40! Pay up old man
# -------------------------
# You are 17 years old kind sir.
# You owe me $40! Pay up old man
# -------------------------
# You are 16 years old kind sir.
# You owe me $40! Pay up old man
