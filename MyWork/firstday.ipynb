# %%
# !conda config --add channels conda-forge
# !conda install -c conda-forge -y git
# !conda install -c conda-forge -y jupyterlab-git

# !conda update -y pexpect
# Out:
# Warning: 'conda-forge' already in 'channels' list, moving to the top
# Jupyter detected...
# 2 channel Terms of Service accepted
# doneieving notices: -
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): /
# doneing environment: |
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - git
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.1.4   |       hbd8a1cb_0         143 KB  conda-forge
#     certifi-2026.1.4           |     pyhd8ed1ab_0         147 KB  conda-forge
#     openssl-3.6.0              |       h5503f6c_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.10.5-hbd8a1cb_0 --> 2026.1.4-hbd8a1cb_0
#   certifi                            2025.10.5-pyhd8ed1ab_0 --> 2026.1.4-pyhd8ed1ab_0
#   openssl                                  3.5.4-h5503f6c_0 --> 3.6.0-h5503f6c_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.6.0        | 3.0 MB    |                                       |   0%
# certifi-2026.1.4     | 147 KB    |                                       |   0%
#
# openssl-3.6.0        | 3.0 MB    | 1                                     |   1%
#
# openssl-3.6.0        | 3.0 MB    | #5                                    |   4%
# certifi-2026.1.4     | 147 KB    | ####                                  |  11%
#
# ca-certificates-2026 | 143 KB    | #################################     |  89%
#
# ca-certificates-2026 | 143 KB    | ##################################### | 100%
#
# ca-certificates-2026 | 143 KB    | ##################################### | 100%
# certifi-2026.1.4     | 147 KB    | ################################1     |  87%
# certifi-2026.1.4     | 147 KB    | ##################################### | 100%
#
#
#
#
# donearing transaction: -
# Verifying transaction: done
# doneuting transaction: -
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: -
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - jupyterlab-git
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jupyterlab-git-0.51.4      |     pyhd8ed1ab_0         298 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         298 KB
#
# The following packages will be UPDATED:
#
#   jupyterlab-git                        0.51.2-pyhd8ed1ab_0 --> 0.51.4-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
#
# donearing transaction: |
# donefying transaction: -
# doneuting transaction: |
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: -
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.

# %%
print('Hello World')
# Out:
# Hello World
